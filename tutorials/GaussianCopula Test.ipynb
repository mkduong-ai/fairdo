# %%
from sdv.demo import load_tabular_demo
from sdv.tabular import GaussianCopula

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = load_tabular_demo('student_placements')

# %%
data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17264      M        67.00      91.00  Commerce        58.00
# 1       17265      M        79.33      78.33   Science        77.48
# 2       17266      M        65.00      68.00      Arts        64.00
# 3       17267      M        56.00      52.00   Science        52.00
# 4       17268      M        85.80      73.60  Commerce        73.30
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 0                55.0   Mkt&HR
# 1    Sci&Tech             True                 1                86.5  Mkt&Fin
# 2   Comm&Mgmt            False                 0                75.0  Mkt&Fin
# 3    Sci&Tech            False                 0                66.0   Mkt&HR
# 4   Comm&Mgmt            False                 0                96.8  Mkt&Fin
#
#    mba_perc   salary  placed start_date   end_date  duration
# 0     58.80  27000.0    True 2020-07-23 2020-10-12       3.0
# 1     66.28  20000.0    True 2020-01-11 2020-04-09       3.0
# 2     57.80  25000.0    True 2020-01-26 2020-07-13       6.0
# 3     59.43      NaN   False        NaT        NaT       NaN
# 4     55.50  42500.0    True 2020-07-04 2020-09-27       3.0

# %%
 model = GaussianCopula()

# %%
 model.fit(data)

# %%
new_data = model.sample(200)

# %%
new_data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17407      M        71.53      71.31   Science        67.02
# 1       17460      F        56.40      43.25  Commerce        71.00
# 2       17454      M        73.65      69.62  Commerce        68.55
# 3       17457      M        62.03      58.19  Commerce        66.65
# 4       17356      M        46.74      54.05   Science        54.12
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech             True                 1               75.97   Mkt&HR
# 1   Comm&Mgmt             True                 1               72.63  Mkt&Fin
# 2    Sci&Tech            False                 1               88.33  Mkt&Fin
# 3   Comm&Mgmt             True                 1               79.98  Mkt&Fin
# 4    Sci&Tech             True                 1               62.68   Mkt&HR
#
#    mba_perc   salary  placed start_date   end_date  duration
# 0     61.46  23971.0    True 2020-07-01 2020-08-08       3.0
# 1     61.11      NaN   False        NaT        NaT       NaN
# 2     54.37      NaN   False        NaT        NaT       NaN
# 3     58.35      NaN   False        NaT        NaT       NaN
# 4     61.92      NaN   False        NaT        NaT       NaN

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# encode non-numeric columns to labels
le = LabelEncoder()
iris_transform = iris.apply(le.fit_transform)

# make species binary
iris_transform['species'] = iris_transform['species'] == 0

# make label
iris_transform['petal_length'] = iris_transform['petal_length'] > 9

# %%
iris_transform.mean()
# Out:
# sepal_length    15.386667
# sepal_width      9.573333
# petal_length     0.660000
# petal_width      8.993333
# species          0.333333
# dtype: float64

# %%
iris_transform.std()
# Out:
# sepal_length    8.175743
# sepal_width     4.323103
# petal_length    0.475296
# petal_width     6.396829
# species         0.472984
# dtype: float64

# %%
model.fit(iris_transform)

# %%
new_samples = model.sample(100)

# %%
new_samples
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0             19           15          True            4    False
# 1             21            7          True           15    False
# 2              3            2         False            4    False
# 3             14            6         False            3    False
# 4             26            5          True           14    False
# ..           ...          ...           ...          ...      ...
# 95            29           16          True            6    False
# 96            22            5          True           11    False
# 97            21            6          True            9    False
# 98            17            6          True           20    False
# 99            23            9          True            7    False
#
# [100 rows x 5 columns]

# %%
model.fit(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 model.fit(data)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sdv\tabular\base.py:139, in BaseTabularModel.fit(self, data)
#     136 LOGGER.debug('Fitting %s to table %s; shape: %s', self.__class__.__name__,
#     137              self._metadata.name, data.shape)
#     138 if not self._metadata_fitted:
# --> 139     self._metadata.fit(data)
#     141 self._num_rows = len(data)
#     143 LOGGER.debug('Transforming table %s; shape: %s', self._metadata.name, data.shape)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sdv\metadata\table.py:620, in Table.fit(self, data)
#     617 elif isinstance(self._field_names, set):
#     618     self._field_names = [field for field in data.columns if field in self._field_names]
# --> 620 self._dtypes = data[self._field_names].dtypes
#     622 if not self._fields_metadata:
#     623     self._fields_metadata = self._build_fields_metadata(data)
#
# File ~\miniconda3\envs\fairness\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\envs\fairness\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\envs\fairness\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',\n       'species'],\n      dtype='object')] are in the [columns]"
